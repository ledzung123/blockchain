# %% [markdown]
# <a href="https://colab.research.google.com/github/ledzung123/blockchain/blob/main/Signature.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !echo "Phong dao tao xac nhan cho sinh vien huy hoc phan" > course_cancel.txt

# !openssl dgst -sha256 -sign private_key.pem -out signature.bin course_cancel.txt

# !echo "--- CHỮ KÝ ĐIỆN TỬ (BASE64) ---"
# !base64 signature.bin
# !echo ""

# !echo "--- KẾT QUẢ XÁC THỰC ---"
# !openssl dgst -sha256 -verify public_key.pem -signature signature.bin course_cancel.txt

# !echo "--- KHI DỮ LIỆU BỊ SỬA ĐỔI (HACKER CAN THIỆP) ---"
# !echo "Phong dao tao khong tao dieu kien cho sinh vien huy hoc phan" > course_cancel.txt
# !openssl dgst -sha256 -verify public_key.pem -signature signature.bin course_cancel.txt
# Out:
# --- CHỮ KÝ ĐIỆN TỬ (BASE64) ---
# VoElP0IyvuP3i1iNRlE/zdCn12pz2hQp1hMj+7W+vh9YjivaYV+sd6XjznA9UL9E3W12VXyKbi+r
# niSxX88wLiCh3m1hpDq7Z2Wf3/AC4ppvr9ENdjxZ9s4yktgjpsDCzgOqILUil1PA7YI1Ijb4Spia
# 3WG9OQ6+IBriTBTV2ztDje8Rb+Qcq4/ZaAqweeAYJJ3hZRhF/e8WffB6CZSF97Wgf2Q9Ey7umbnN
# hy9AL+Fkqa1+3TPDIIvRqmL4xqxJRuU6KBxUeud8i9ReL04PZO7FC09K00PhJf0ihfzGIYbkGNTj
# +I+vaW+ltNiZ9XuLmKYvQE9Bpjzrtoqaq39QKQ==
#
# --- KẾT QUẢ XÁC THỰC ---
# Verified OK
# --- KHI DỮ LIỆU BỊ SỬA ĐỔI (HACKER CAN THIỆP) ---
# Verification failure
# 40C723CBE67F0000:error:02000068:rsa routines:ossl_rsa_verify:bad signature:../crypto/rsa/rsa_sign.c:430:
# 40C723CBE67F0000:error:1C880004:Provider routines:rsa_verify:RSA lib:../providers/implementations/signature/rsa_sig.c:774:
